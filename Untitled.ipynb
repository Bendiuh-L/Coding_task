# %%
import pandas as pd
import numpy as np
import warnings

# %%
data=pd.read_csv("hotels-vienna.csv", encoding="utf-8")

# %%
data.describe().transpose() #creating statistics table
# Out:
#                 count          mean         std      min       25%      50%  \
# rating_count    393.0    155.048346  191.217435      1.0     27.00     84.0
# price           428.0    131.366822   91.580545     27.0     83.00    109.5
# stars           428.0      3.434579    0.772278      1.0      3.00      3.5
# ratingta        325.0      3.990769    0.482638      2.0      3.50      4.0
# ratingta_count  325.0    556.516923  586.874582      2.0    129.00    335.0
# scarce_room     428.0      0.598131    0.490850      0.0      0.00      1.0
# hotel_id        428.0  22153.502336  146.858477  21894.0  22027.75  22155.5
# offer           428.0      0.679907    0.467058      0.0      0.00      1.0
# year            428.0   2017.000000    0.000000   2017.0   2017.00   2017.0
# month           428.0     11.000000    0.000000     11.0     11.00     11.0
# weekend         428.0      0.000000    0.000000      0.0      0.00      0.0
# ...

# %%
data.filter(["price", "stars", "distance_alter"]).describe().transpose()
# Out:
#                 count        mean        std   min   25%    50%    75%     max
# price           428.0  131.366822  91.580545  27.0  83.0  109.5  146.0  1012.0
# stars           428.0    3.434579   0.772278   1.0   3.0    3.5    4.0     5.0
# distance_alter  428.0    3.718458   1.631341   0.6   2.7    3.4    4.4    13.0

# %%
data.shape
# in order to see how many observations and variables we have before dropping missing values
# Out:
# (428, 24)

# %%
data.loc[data["accommodation_type"] == "Pension"] # choosing hotels depending on their type of accommodation
# Out:
#      country city_actual  rating_count center1label center2label  \
# 65   Austria      Vienna          83.0  City centre    Donauturm
# 79   Austria      Vienna         109.0  City centre    Donauturm
# 119  Austria      Vienna         278.0  City centre    Donauturm
# 124  Austria      Vienna         203.0  City centre    Donauturm
# 135  Austria      Vienna          69.0  City centre    Donauturm
# 139  Austria      Vienna          65.0  City centre    Donauturm
# 141  Austria      Vienna          11.0  City centre    Donauturm
# 142  Austria      Vienna          51.0  City centre    Donauturm
# 146  Austria      Vienna          66.0  City centre    Donauturm
# 158  Austria      Vienna          65.0  City centre    Donauturm
# 170  Austria      Vienna          90.0  City centre    Donauturm
# 275  Austria      Vienna          49.0  City centre    Donauturm
# 278  Austria      Vienna          55.0  City centre    Donauturm
# ...

# %%
data["rating_count"].isnull().sum() # checking how many missing values there are
# Out:
# 35

# %%
data.loc[data["rating_count"].isnull()] # missing values of rating_count are showed
# Out:
#      country city_actual  rating_count center1label center2label  \
# 9    Austria      Vienna           NaN  City centre    Donauturm
# 14   Austria      Vienna           NaN  City centre    Donauturm
# 19   Austria      Vienna           NaN  City centre    Donauturm
# 33   Austria      Vienna           NaN  City centre    Donauturm
# 45   Austria      Vienna           NaN  City centre    Donauturm
# 66   Austria      Vienna           NaN  City centre    Donauturm
# 75   Austria      Vienna           NaN  City centre    Donauturm
# 76   Austria      Vienna           NaN  City centre    Donauturm
# 82   Austria      Vienna           NaN  City centre    Donauturm
# 83   Austria      Vienna           NaN  City centre    Donauturm
# 84   Austria      Vienna           NaN  City centre    Donauturm
# 85   Austria      Vienna           NaN  City centre    Donauturm
# 97   Austria      Vienna           NaN  City centre    Donauturm
# ...

# %%
data = data.loc[data["rating_count"].notnull()] # dropping missing values from rating_count category

# %%
data["rating_count"].isnull().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (393, 24)

# %%
data.duplicated().sum()
#looking is there any aplicates
# Out:
# 0

# %%
data.drop(
    columns=[
        "distance_alter",
        "offer",
    ],
    inplace=True,
)
# getting read of some unnecessary variables

# %%
data.describe().transpose()
# Out:
#                 count          mean         std      min      25%      50%  \
# rating_count    393.0    155.048346  191.217435      1.0     27.0     84.0
# price           393.0    127.659033   89.947495     27.0     82.0    107.0
# stars           393.0      3.441476    0.795642      1.0      3.0      3.5
# ratingta        322.0      3.996894    0.465297      2.5      3.5      4.0
# ratingta_count  322.0    561.453416  587.351683      2.0    136.5    340.5
# hotel_id        393.0  22159.730280  147.554948  21894.0  22034.0  22162.0
# weekend         393.0      0.000000    0.000000      0.0      0.0      0.0
# distance        393.0      1.707379    1.626541      0.0      0.8      1.4
# nnights         393.0      1.000000    0.000000      1.0      1.0      1.0
# rating          393.0      3.970992    0.577444      1.0      3.7      4.0
#
#                      75%      max
# rating_count      203.00   1541.0
# price             142.00   1012.0
# stars               4.00      5.0
# ...

# %%
new = data.columns.tolist()
print(new)
# Out:
# ['country', 'rating_count', 'center1label', 'center2label', 'neighbourhood', 'price', 'city', 'stars', 'ratingta', 'ratingta_count', 'hotel_id', 'weekend', 'distance', 'accommodation_type', 'nnights', 'rating']

# %%
for hotel_id, stars in zip(data['hotel_id'], data['stars']):
    if stars >= 3:
        print(f"{hotel_id} is good")
    else:
        print(f"{hotel_id} is bad")
# making automative repeating hotels with number of stars
# Out:
# 21894 is good
# 21897 is good
# 21901 is good
# 21902 is good
# 21903 is good
# 21904 is good
# 21906 is good
# 21907 is good
# 21908 is bad
# 21912 is good
# 21913 is good
# 21914 is good
# 21915 is bad
# 21917 is good
# 21918 is good
# 21919 is good
# 21920 is good
# 21922 is good
# 21924 is good
# 21925 is good
# 21926 is good
# 21927 is good
# 21928 is good
# 21930 is good
# 21933 is good
# 21934 is bad
# 21935 is good
# 21936 is bad
# 21937 is bad
# 21938 is good
# 21940 is good
# 21941 is good
# 21943 is good
# 21945 is bad
# 21946 is good
# 21947 is bad
# 21948 is bad
# 21949 is bad
# 21950 is good
# 21951 is bad
# 21956 is bad
# 21959 is good
# 21960 is good
# 21962 is good
# 21963 is good
# 21964 is good
# 21965 is good
# 21966 is good
# 21967 is good
# 21968 is good
# 21969 is good
# 21970 is good
# 21971 is good
# 21972 is good
# 21973 is good
# 21975 is good
# 21976 is good
# 21977 is good
# 21979 is good
# 21980 is good
# 21981 is good
# 21984 is good
# 21985 is good
# ...

# %%
data.price.hist() # creating histogram
# Out:
# <AxesSubplot:>

# %%
data.to_csv("vienna_hotels.csv", index=False) # saving work
